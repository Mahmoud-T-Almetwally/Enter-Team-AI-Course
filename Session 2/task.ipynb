# %% [markdown]
# **Instructions:**
# 1.  Read the explanations and instructions for each problem carefully.
# 2.  Write your code in the code cells provided.
# 3.  Run the cells to see the output of your code.
# 4.  Compare your results with the expected output.\
# __Ensure you activated your environment and are running the correct kernel (check the 'EnvironmnetSetup-02.pdf' in session 1)__

# %%
import numpy as np
import sys

# DON'T CHANGE:
sys.path.append("..")

try:
    from assessment import task02
except:
    raise ImportError("Can't Import Assessment! Assessment Module Missing, ensure you have the complete code, or get it from: https://github.com/Mahmoud-T-Almetwally/Enter-Team-AI-Course.git")

# %% [markdown]
# ---
# ### Problem 1: Creating Your First Vectors and Matrices
#
# **Goal:** Get comfortable creating NumPy arrays.
#
# **a) Create a 1D NumPy array (a vector) named `my_vector` that contains the numbers from 1 to 5.**

# %%
# Your Code Here (replace the three dots '...'):
my_vector = ...

# %%
task02.check_my_vector(my_vector)

# %% [markdown]
# **b) Create a 2D NumPy array (a 3x3 matrix) named `my_matrix` with the given values.**
#
# ```
# [1, 2, 3,
#  4, 5, 6,
#  7, 8, 9]
# ```

# %%
# Your Code Here (replace the three dots '...'):
my_matrix = ...

# %%
task02.check_my_matrix(my_matrix)

# %% [markdown]
# **c) check the dimensions of `my_vector` and `my_matrix`.**

# %%
# Your Code Here (replace the three dots '...'):
print(f"Shape of my_vector: {...}")
print(f"Shape of my_matrix: {...}")

# %% [markdown]
# ---
# ### Problem 2: Array Arithmetic
#
# **Goal:** Practice performing basic mathematical operations on NumPy arrays.
#
# **a) Add the number `5` to every element in `my_vector`.**

# %%
# Your Code Here (replace the three dots '...'):
my_vector = ...

# %%
task02.check_added_5(my_vector)

# %% [markdown]
# **b) Multiply every element in `my_matrix` by `2`.**

# %%
# Your Code Here (replace the three dots '...'):
my_matrix = ...

# %%
task02.check_multiplied_by_2(my_matrix)

# %% [markdown]
# **c) Create a new 3x3 matrix called `another_matrix` and add it to `my_matrix`.**
#
# ```
# [9, 8, 7,
#  6, 5, 4,
#  3, 2, 1]
# ```

# %%
# Your Code Here (replace the three dots '...'):
another_matrix = ...
result = ...

# %%
task02.check_added_matrices(result)

# %% [markdown]
# ---
# ### Problem 3: Broadcasting
#
# **Goal:** Understand how NumPy handles operations between arrays of different (but compatible) shapes.
#
# You are given a 3x4 matrix `sales_data` representing the sales of 3 products over 4 quarters. You are also given a 1D array `quarterly_bonus` representing a bonus amount for each quarter.
#
# Add the bonus to the sales data for each product.

# %%
# DON'T CHANGE:
sales_data = np.array([[100, 120, 150, 130],
                       [200, 210, 220, 240],
                       [50, 60, 40, 70]])

quarterly_bonus = np.array([10, 12, 15, 13])

# Your Code Here (replace the three dots '...'):
total_earnings = ...

# %%
task02.check_total_earnings(total_earnings)

# %% [markdown]
# ---
# ### Problem 4: Matrix Multiplication (The Dot Product)
#
# **Goal:** This is the most important operation in Linear Algebra for Machine Learning. Let's practice it.
#
# You are given two matrices, `A` and `B`.
#
# **a) Before you write any code, what will be the shape of the resulting matrix when you multiply `A` and `B`?**
# *   Matrix `A` has shape (3, 2)
# *   Matrix `B` has shape (2, 4)

# %%
# Your Code Here (replace the three dots '...'):
# Note: write your answer in a tuple, i.e. (,).
answer = ...

# %%
task02.check_answer(answer)

# %% [markdown]
# **b) Now, perform the matrix multiplication of `A` and `B` and store the result in a variable called `C`.**

# %%
A = np.array([[1, 2],
              [3, 4],
              [5, 6]])

B = np.array([[2, 3, 4, 5],
              [6, 7, 8, 9]])

# Your Code Here (replace the three dots '...'):
C = ...
print(f"Matrix C :\n{...}")
print(f"Shape of C: {...}")

# %%
task02.check_C(C)

# %% [markdown]
# ---
# ### Problem 5: Mini Challenge - Predicting Housing Prices
#
# **Goal:** See how these concepts directly apply to a simple machine learning problem.
#
# Imagine you have a dataset of 3 houses. For each house, you have two features: `size (sq ft)` and `number of bedrooms`. This is represented by the matrix `X`.
#
# You also have a set of "weights" learned by a machine learning model. One weight for each feature. This is represented by the vector `w`.
#
# The predicted price for each house is calculated by the dot product of its features and the weights.
#
# **Your task: Calculate the predicted prices for all three houses using a single matrix multiplication.**

# %%
# DON'T CHANGE:
# Dataset of 3 houses (rows) and 2 features (columns)
X = np.array([[1500, 3],  # House 1: 1500 sq ft, 3 bedrooms
              [2200, 4],  # House 2: 2200 sq ft, 4 bedrooms
              [1200, 2]]) # House 3: 1200 sq ft, 2 bedrooms

# Weights learned by a model
w = np.array([300, 20000]) # $300 per sq ft, $20000 per bedroom

# Your Code Here (replace the three dots '...'):
predicted_prices = ...

print(f"Predicted prices: {predicted_prices}")

# %%
task02.check_predicted_prices(predicted_prices)

# %%
# DON'T CHANGE:
task02.check_pass()
